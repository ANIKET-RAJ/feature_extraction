# %%
from matplotlib import pyplot as plt
from skimage import data
import glob
from skimage.io import imread
import pandas as pd
import numpy as np
from pandas import DataFrame
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
xf = pd.read_excel('C:/Users/ANIKET RAJ/Desktop/ICIAR2018/codes/area_counters_code/result_count.xlsx')
df=pd.DataFrame(xf)
df
# Out:
#                 name  count  label  cancer_label  log  dog
# 0    Benign\b001.tif    468      2             0  120  496
# 1    Benign\b002.tif   1630      2             0  164  480
# 2    Benign\b003.tif   1023      2             0  142  467
# 3    Benign\b004.tif   1339      2             0  232  473
# 4    Benign\b005.tif   1011      2             0  212  463
# 5    Benign\b006.tif   1105      2             0  243  409
# 6    Benign\b007.tif   1303      2             0  351  446
# 7    Benign\b008.tif   1691      2             0  295  580
# 8    Normal\n093.tif   3484      1             0  428  523
# 9    Normal\n094.tif   3157      1             0  260  446
# 10   Normal\n095.tif   3304      1             0   80  460
# 11   Normal\n096.tif   1652      1             0  156  437
# 12   Normal\n084.tif   4590      1             0  105  421
# 13   Benign\b014.tif   1472      2             0  223  394
# 14   Benign\b015.tif   1048      2             0  167  430
# ...

# %%
X=np.array(df['count'])
y=np.array(df['label'])
X=X.reshape(-1,1)
#y=y.reshape(-1,1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,shuffle=True)
clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#xxf = pd.read_excel('C:/Users/ANIKET RAJ/Desktop/ICIAR2018/codes/area_counters_code/test.xlsx')
#ddf=pd.DataFrame(xxf)
#ddf

# %%
y_pred=clf.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.25

# %%
#X_test=np.array(ddf['count'])
#y_test=np.array(ddf['label'])
#X_test=X_test.reshape(-1,1)

# %%
#y_pred=clf.predict(X_test)
#print(accuracy_score(y_test, y_pred))
# Out:
# 0.235294117647
